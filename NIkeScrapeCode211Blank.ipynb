# %% [markdown]
# # Import All Library

# %%
from bs4 import BeautifulSoup
import requests
import re
import html5lib
import pandas as pd

# %% [markdown]
# # Take the URL and Open

# %%
URL = "https://www.nike.com/w/men-shoes-nik1zy7ok"
r = requests.get(URL)

# %% [markdown]
# # Make the Soup object

# %%
soup = BeautifulSoup(r.content, 'html5lib') #scrape the html
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <script type="text/javascript">
# ...

# %% [markdown]
# # Make List of Shoe Cards

# %% [markdown]
# # Print the First Item for Reference

# %% [markdown]
# # Store Necessary Data

# %% [markdown]
# # Creating Panda Dataframe

# %%
export_excel = test_df.to_excel (r'C:\Users\Riki T\Desktop\export_dataframe.xlsx', index = None, header=True) #Don't forget to add '.xlsx' at the end of the path

# %% [markdown]
# # Leveling Up
# ## First Get the URL of each Card

# %% [markdown]
# # Put into Pandas
